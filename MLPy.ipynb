# %% [markdown]
# <a href="https://colab.research.google.com/github/sujitkarunakar/pythonml/blob/master/MLPy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
L1=[2,4,6,8,10]
#L2=L1
L2:L1.copy
print(L2)
L2=[2,4,6,8,10]
del L2[-1]
del L2[1:5]
# Out:
# [2, 4, 6]

# %%
import numpy as np
import tensorflow as tf

# %%
my_tuple = (1, 2, 3)
print(my_tuple)
my_tuple1 = ("mouse", [8, 4, 6], (1, 2, 3))
print(my_tuple1)
# Out:
# (1, 2, 3)
# ('mouse', [8, 4, 6], (1, 2, 3))

# %%
import numpy as np 
import math 
  
in_array = np.arange(360.) * 90
print ("Degree values : \n", in_array) 
  
radian_Values = np.radians(in_array) 
print ("\nRadian values : \n", radian_Values)
# Out:
# Degree values :
#  [    0.    90.   180.   270.   360.   450.   540.   630.   720.   810.
#    900.   990.  1080.  1170.  1260.  1350.  1440.  1530.  1620.  1710.
#   1800.  1890.  1980.  2070.  2160.  2250.  2340.  2430.  2520.  2610.
#   2700.  2790.  2880.  2970.  3060.  3150.  3240.  3330.  3420.  3510.
#   3600.  3690.  3780.  3870.  3960.  4050.  4140.  4230.  4320.  4410.
#   4500.  4590.  4680.  4770.  4860.  4950.  5040.  5130.  5220.  5310.
#   5400.  5490.  5580.  5670.  5760.  5850.  5940.  6030.  6120.  6210.
#   6300.  6390.  6480.  6570.  6660.  6750.  6840.  6930.  7020.  7110.
#   7200.  7290.  7380.  7470.  7560.  7650.  7740.  7830.  7920.  8010.
#   8100.  8190.  8280.  8370.  8460.  8550.  8640.  8730.  8820.  8910.
#   9000.  9090.  9180.  9270.  9360.  9450.  9540.  9630.  9720.  9810.
#   9900.  9990. 10080. 10170. 10260. 10350. 10440. 10530. 10620. 10710.
#  10800. 10890. 10980. 11070. 11160. 11250. 11340. 11430. 11520. 11610.
# ...
